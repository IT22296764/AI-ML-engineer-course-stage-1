# %% [markdown]
# <a href="https://colab.research.google.com/github/bashiimalsha/AI-ML-engineer-course-stage-1/blob/main/Image_Filtering(Convolution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # **Load the image using OpenCV**

# %%
im = cv2.imread('/content/sample_data/Lena-image.png')

# %%
im.shape
# Out:
# (567, 567, 3)

# %% [markdown]
# ### **Convert the RGB image into a grayscale image**

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im.shape
# Out:
# (567, 567)

# %% [markdown]
# ### **Define vertical and horizontal filter Kernels**

# %%
v_Kerel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
])


h_kernel = np.array([

       [-1, -1, -1],
       [0, 0, 0],
       [1, 1, 1]
])

# %% [markdown]
# **6)**

# %%
h_image = cv2.filter2D(im, -1, h_kernel)

# %%
plt.imshow(im, cmap='gray')
plt.title('Original Image')

plt.figure()
plt.imshow(h_image, cmap='gray')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='gray')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')
